# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sds = pd.read_csv('stds.csv',names=['month','60','70'])

# %%
plt.figure()
plt.plot(sds.index,sds['60'])
plt.plot(sds.index,sds['70'])
plt.ylim(12,4)
plt.show()
